# %% [markdown]
# <a href="https://colab.research.google.com/github/WINIRAIS/ADA-Informes/blob/main/MergeSort.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Problema de Ordenamiento MergeSort

# %% [markdown]
# **Entrada**: Una secuencia de números de tamaño N  $[a_1,a_2,...,a_n]$\
# Esto refiere a que se tendrá una serie de números los cuales estarán en un orden disperso como se muestra en la imagen de a continuación, ojo que si la longitud de la lista o arreglo es 0 o 1 , este ya esta ordenado.\
# **Salida** : La misma secuencia ordenada de tal manera que   [$a_1' \leq a_2' \leq a_3' .... \leq a_n'$] \
# Esto indica que la misma secuencia ingresada anteriormente se mostrara ordenada de menor a mayor.
#
# <img style="display: block;-webkit-user-select: none;margin: auto;cursor: zoom-in;background-color: hsl(0, 0%, 90%);" src="https://i.stack.imgur.com/IKEHS.jpg" width="300" height="342">

# %% [markdown]
# # 2. Merge Sort

# %% [markdown]
# El siguiente código muestra la implementación del **Merge sort**

# %% [markdown]
# # 2.1. Código

# %%
import random
from termcolor import colored

def MergeSort(A, verbose):
   global count_recur # contador de veces que se llama a si misma
   global entrar
   count_recur+=1
   if verbose: 
     if(entrar == 0):
        print("input array:",a)
     entrar=1

   if len(A) == 1 or len(A) == 0: 
     return A  #si el largo del array es 0 o 1 indica que ya esta ordenado
   else:
     if len(A) > 1:
      mitad = ((len(A))//2) #elemento medio del arreglo
      lado_izq = A[:mitad] #ordena la parte izquierda del arreglo que va del inicio hasta la mitad
      lado_der = A[mitad:] #ordena la parte derecha del arreglo que va de la mitad hasta el final

      #Se llama Recursivamente
      MergeSort(lado_izq,verbose)
      MergeSort(lado_der,verbose) 
      Merge(lado_izq,lado_der,A,verbose)
    
#Función Merge reordena todos los elementos en un arreglo

def Merge(izq,der,A,verbose):
  i=0 #indices
  j=0 #indices
  k=0 #indices 
  global comp #numero de comparaciones realizadas
  global numero_llemadas
  array = A

  if verbose:
      print(colored(f"Pasada {numero_llemadas}","green"))
      numero_llemadas += 1
      print(colored("subdivisiones:","blue"))
      print(izq," y ",der)
      print(colored("Proceso:","blue"))
  while(i < len(izq) and j < len(der)):
    if izq[i] < der[j]:
      array[k] = izq[i]
      i += 1
    else:
      array[k] = der[j]
      j += 1
    comp +=1
    k += 1
    if verbose:mostrar(array,k)
  
  while i < len(izq):
            array[k] = izq[i]
            i += 1
            k += 1
            comp +=1
            if verbose:mostrar(array,k)

  while j < len(der):
            array[k] = der[j]
            j += 1
            k += 1
            comp +=1
            if verbose:mostrar(array,k)
 
  return array

#Mostrar Arreglo
def mostrar(A, k):
  print("[", end="")
  for i in range(0, k):
    if (i == 0):
      print(A[i], end="")
    else:
      print(",",A[i], end="")
  print("]")

A = [39,27,43,3,9,82,10]
print(colored("Entrada: ","blue"),A)
comp = 0
count_recur = -1
entrar = 0
numero_llemadas=1
verbose = False
MergeSort(A,verbose)
print(colored("Salida: ","red"),A)
print("Número de veces que se llamo MergeSort:",colored(f"{str(count_recur)}","blue"))
print("Número de comparaciones realizadas:",colored(f"{str(comp)}","blue"))
# Out:
# Entrada:  [39, 27, 43, 3, 9, 82, 10]
# Salida:  [3, 9, 10, 27, 39, 43, 82]
# Número de veces que se llamo MergeSort: 12
# Número de comparaciones realizadas: 20

# %%
import random 
from termcolor import colored


def InsertionSort (Array):
  T = 0 #contador de comparaciones

 
  for j in range (1, len(Array)):
    elem_comparacion = Array[j]
    i = j-1
    while(i >= 0) and (Array[i] > elem_comparacion ):
      Array[i+1] = Array[i]
      i = i -1
      T += 1
      
    Array[i+1] = elem_comparacion
    if  i >= 0 : T+=1


  return Array,T

A = [5,3,2,1,4,6]
print("Entrada: ",A)
A, counter = InsertionSort(A)
print("Salida: ",A)
print("# comparaciones: ", counter)
# Out:
# Entrada:  [5, 3, 2, 1, 4, 6]
# Salida:  [1, 2, 3, 4, 5, 6]
# # comparaciones:  9

# %% [markdown]
# # 2.2. Descripción del algoritmo

# %% [markdown]
# El algoritmo recibe una lista o un arreglo A con una cantidad de N elementos desordenados que deseamos ordenar, donde estos mismos elemento que en un principio estaban desordenados quedaran ordenados del modo que se estime conveniente , para nuestro caso será de menor a mayor, cabe destacar que este es un algoritmo de "divide y venceras", donde la creación del mismo es implementada de manera recursiva, es decir se llama a el mismo.
#
#
# 1.   Ordena la mitad izquierda `MergeSort(lado_izq)`
# 2.   Luego ordena la mitad derecha `MergeSort(lado_der)`
# 3.   Finalmente mezcla ambas mitades para obtener un arreglo o lista ordenado `Merge(lado_izq,lado_der,A,verbose)`

# %% [markdown]
# Notese de que si el arreglo o lista es de largo 1 o 0 , el algoritmo se detrenda asumiendo de que este ya esta ordenado

# %% [markdown]
# # 2.3. Ejemplo
# Consideremos el arreglo: \
# $a= [5, 7, 8, 1, 3]$\
# Como se mostro en la imagen anterior este se va subdividiendo en 2 para poder llegar a comparar al final de un elemento a la vez, por lo que nos quedaria en este caso \
# ![MergeSort.png](data:image/png;base64,...)

# %% [markdown]
# Cabe destacar que nuestro array con indice $i$ es el del lado izquierdo y el del lado derecho utiliza el indice $j$\
# Posterio a esto se procede a ocupar la funcion $merge$ para reordenar todos los elementos en un solo arreglo , o lista.

# %% [markdown]
# ![MergeSort.png](data:image/png;base64,...)

# %% [markdown]
# # 2.4. Ejecución del algoritmo paso a paso (verbose=True)

# %% [markdown]
# Con la opción verbose `True` se podra ver lo que ocurre paso a paso

# %%
import random
var = random.randint(1,7)
comp = 0
count_recur = -1
entrar = 0
numero_llemadas=1
a = random.sample(range(1, 100), var)
MergeSort(a,verbose=True)
print("\n")
print(colored("Salida : ","red"), a)
print("Numero de veces que se llamo MergeSort:",colored(f"{str(count_recur)}","blue"))
print("Numero de comparaciones realizadas:",colored(f"{str(comp)}","blue"))
# Out:
# input array: [47, 99, 46, 9, 78, 33, 85]
# Pasada 1
# subdivisiones:
# [99]  y  [46]
# Proceso:
# [46]
# [46, 99]
# Pasada 2
# subdivisiones:
# [47]  y  [46, 99]
# Proceso:
# [46]
# [46, 47]
# [46, 47, 99]
# Pasada 3
# subdivisiones:
# [9]  y  [78]
# Proceso:
# [9]
# [9, 78]
# Pasada 4
# subdivisiones:
# [33]  y  [85]
# Proceso:
# [33]
# [33, 85]
# Pasada 5
# subdivisiones:
# [9, 78]  y  [33, 85]
# Proceso:
# [9]
# [9, 33]
# [9, 33, 78]
# [9, 33, 78, 85]
# Pasada 6
# subdivisiones:
# [46, 47, 99]  y  [9, 33, 78, 85]
# Proceso:
# [9]
# [9, 33]
# [9, 33, 46]
# [9, 33, 46, 47]
# [9, 33, 46, 47, 78]
# [9, 33, 46, 47, 78, 85]
# [9, 33, 46, 47, 78, 85, 99]
#
#
# Salida :  [9, 33, 46, 47, 78, 85, 99]
# Numero de veces que se llamo MergeSort: 12
# Numero de comparaciones realizadas: 14

# %% [markdown]
# 3. **Tiempo de ejecución** \
# **Teorema (Tiempo de ejecución).**
# 1. El algoritmo **Merge Sort** tiene un `tiempo de ejecución` de **o($nlog(n)$)** en cualquiera de los casos
# # Prueba del teorema
#
# ![image](https://cdn.kastatic.org/ka-perseus-images/5fcbebf66560d8fc490de2a0d8a0e5b1d65c5c54.png)

# %% [markdown]
# Aquí se puede apreciar lo que ocurre cuando vamos subdividiendo un arreglo de tamaño $n$ , donde también se puede apreciar los tiempos de mezcla de este, que sería en nuestro caso la constante "$cn$" , ahora sabemos que el tiempo total para MergeSort es la suma de los tiempos de mezcla para todos los niveles, por ende si tenemos una cantidad "**X**" de niveles, la formula seria $X*cn$, donde "x =  $log_2n +1$" ésta afirmación cumple con los niveles que tendrá nuestro tipo de árbol, ya que si por ejemplo nuestro arreglo es de 8 elementos  nuestra n = 8, y si lo reemplazamos x =  $log_2"8" +1$ = 4 donde el árbol tendrá efectivamente los 4 niveles , por ende ahora reemplazamos la x por la fórmula propuesta donde nos quedara $log_2n +1*cn$ donde sabemos que para calcular la complejidad debemos eliminar las constantes y dejar todo en función a $n$, por lo que nos quedaría $O(n(logn))$.

# %% [markdown]
# # 4. Correctitud
#
# ### **Teorema (Correctitud).**
#
# El algoritmo **MergeSort** genera un arreglo: $[a_1',a_2',...,a_n']$, con los mismos elementos del arreglo de entrada ordenados de menor a mayor, es decir,  $a_1'\leq a_2' \leq... \leq a_n'$.
#
# ## Prueba del Teorema
#
# ###**Propiedad invariante de bucle (Merge)**
# Esta propiedad consiste en que los dos arreglos de entrada ya se encuentran ordenados, y que utilizando la función Merge, resultará en la unión ordenada de los dos arreglos.
#
# **Inicialización:**
# La primera vez que se llama a esta función, se le entregan dos arreglos de largo $1$, esto quiere decir que como sólo tienen un elemento, ya de por sí están ordenados.
#
# **Mantención:**
# Al usar el Merge entre dos arreglos ordenados (Entrada), lo que ocurre es que se comprueba entre los primeros elementos de los arreglos para ver cuáles son los menores, y se va generando un arreglo ordenado compuesto por la unión de los dos de entrada (Tal como se vió en el ejemplo paso a paso con verbose = True).
#
# **Correctitud**
#
# Finalmente, como la propiedad de bucle invariante es verdadera al incio del bucle y se mantiene en cada iteración, podemos decir que al **finalizar la n-ésima iteración del algoritmo**, se que genera un arreglo $[a_1',a_2',...,a_n']$, con los mismos elementos del arreglo de entrada ordenados de menor a mayor. $\Box$
# ##  Correctitud por inducción (MergeSort)
# Para probar la correctitud de algoritmos recursivos usaremos inducción matemática.
# En inducción matemática, para probar una declaración $P(n)$, para todos los números naturales $n$, típicamente debemos:
#
# - Probar $P(n)$ para un **caso base**, por ejemplo $P(1)$
# - Probar que si $P(m)$ es cierto para $m < n$, entonces $P(n)$ también lo es.
#
# **$P(1)$:** Este caso es verdadero, debido a que si se le entrega un arreglo de largo $1$, lo devolverá ordenado, ya que contiene un sólo elemento.
#
# **$P(m)$:** Se conoce de que el arreglo se va subdividiendo en dos (Como se mostró anteriormente con el árbol de recursión), lo que provoca que si se tiene un arreglo de largo $n$, se subdivide en dos arreglos de largo $m = [n/2]$ y $m = [n/2]$ y son ordenadas con MergeSort (Demostrado por la propiedad invariante de bucle de función Merge).
# Con lo anterior, se demuestra que el algoritmo MergeSort, ordena exitosamente un arreglo de largo $n$ de menor a mayor.

# %% [markdown]
# # 5. Experimentos

# %% [markdown]
# # 5.1. Número de comparaciones
#
# A continuación se muestra gráficamente una comparación entre:
#
# * cantidad de comparaciones del peor caso calculadas matemáticamente,
# * cantidad de comparaciones del mejor caso calculadas matemáticamente (n-1 comparaciones si el arreglo está ordenado)
# * cantidad de comparaciones realizadas experimentalmente para entradas aleatorias
#
# para tamaños de problemas con $n \in [5,20]$.
#
# Los arreglos de entrada son generados aleatoriamente haciendo un sampling de un conjunto de números entre 1 y 100.

# %%
import matplotlib.pyplot as plt
import math

x=[n for n in range(5,20)] 
y1=[n* math.log2(n) for n in range(5,20)] # pero caso
y2=[n* math.log2(n) for n in range(5,20)] # mejor caso
y=[]; 

for n in range(5,20):
  a = random.sample(range(1, 100), n)
  verbose=False
  comp = 0
  a = MergeSort(a,verbose)
  y.append(comp)

plt.plot(x,y,color='red')
plt.plot(x,y1,color='blue')
plt.plot(x,y2,color='black')
plt.legend(["Merge Sort", "Peor caso teoricamente", "Mejor caso teoricamente"])


plt.xlabel('n')
plt.ylabel('number of operations')
plt.show()

# %% [markdown]
# **Análisis de resultados**
#
# Como se puede observar los comportamientos son casi iguales ya que , el mejor y el peor caso teoricamente tambien lo son, donde se deja en evidencia que la complejidad del algoritmo tiene una **cota asintotica** de orden $𝚯(nlog(n))$, es decir $O(nlog(n)) = Ω(nlog(n))$ .

# %% [markdown]
# # 5.2. Tiempo de ejecución(experimental)
# En el siguiente gráfico se reporta el tiempo de ejecución del algoritmo **MergeSort** en función del tamaño del problema para arreglos generados aleatoriamente de tamaños entre $5$ y $500$.

# %%
import matplotlib.pyplot as plt
import datetime
from timeit import repeat

x=[]; y=[];y2=[]

for n in range(5,500):

  a = random.sample(range(1, 1000), n)

  #la función repeat está ejecutando 20 veces InsertionSort con el arreglo a y retorna el mejor tiepo obtenido.
  t = repeat(setup="from __main__ import MergeSort", stmt=f"MergeSort({a},{False})", repeat=1, number=10)
  t2 = repeat(setup="from __main__ import InsertionSort", stmt=f"InsertionSort({a})", repeat=1, number=10)

  x.append(n)
  y.append(t)
  y2.append(t2)


plt.plot(x,y)
plt.plot(x,y2)
plt.legend(["MergeSort","InsertionSort"])


plt.xlabel('n')
plt.ylabel('time in ms')
plt.show()

# %% [markdown]
# ### Análisis de resultados
#
# La comparación en relación al tiempo de ambos algoritmos deja en evidencia de que el MergeSort es mucho mejor que el InsertionSort, ya que como se puede observar, el insertionSort tiene un comportamiento prácticamente cuadrático, y el mergeSort tiene uno casi lineal obteniendo valores en el eje Y que es el tiempo mucho mas bajos que el InsertionSort.
